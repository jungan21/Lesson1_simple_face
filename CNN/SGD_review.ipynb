# %% [markdown]
# # SGD - 老师的文件，课上未做解释

# %%
# y = (x - 1) ** 2

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
xs = []
ys = []
for x in np.arange(-1,4,0.05):
    xs.append(x)
    ys.append((x - 1) ** 2)

# %%
pd.DataFrame({
     'xs':xs,
     'ys':ys
})
# Out:
#               xs      ys
# 0  -1.000000e+00  4.0000
# 1  -9.500000e-01  3.8025
# 2  -9.000000e-01  3.6100
# 3  -8.500000e-01  3.4225
# 4  -8.000000e-01  3.2400
# 5  -7.500000e-01  3.0625
# 6  -7.000000e-01  2.8900
# 7  -6.500000e-01  2.7225
# 8  -6.000000e-01  2.5600
# 9  -5.500000e-01  2.4025
# 10 -5.000000e-01  2.2500
# 11 -4.500000e-01  2.1025
# 12 -4.000000e-01  1.9600
# 13 -3.500000e-01  1.8225
# 14 -3.000000e-01  1.6900
# 15 -2.500000e-01  1.5625
# 16 -2.000000e-01  1.4400
# 17 -1.500000e-01  1.3225
# 18 -1.000000e-01  1.2100
# 19 -5.000000e-02  1.1025
# 20  8.881784e-16  1.0000
# 21  5.000000e-02  0.9025
# 22  1.000000e-01  0.8100
# 23  1.500000e-01  0.7225
# 24  2.000000e-01  0.6400
# 25  2.500000e-01  0.5625
# 26  3.000000e-01  0.4900
# 27  3.500000e-01  0.4225
# 28  4.000000e-01  0.3600
# 29  4.500000e-01  0.3025
# ..           ...     ...
# 70  2.500000e+00  2.2500
# 71  2.550000e+00  2.4025
# 72  2.600000e+00  2.5600
# 73  2.650000e+00  2.7225
# 74  2.700000e+00  2.8900
# 75  2.750000e+00  3.0625
# 76  2.800000e+00  3.2400
# 77  2.850000e+00  3.4225
# 78  2.900000e+00  3.6100
# 79  2.950000e+00  3.8025
# 80  3.000000e+00  4.0000
# 81  3.050000e+00  4.2025
# 82  3.100000e+00  4.4100
# 83  3.150000e+00  4.6225
# 84  3.200000e+00  4.8400
# 85  3.250000e+00  5.0625
# 86  3.300000e+00  5.2900
# 87  3.350000e+00  5.5225
# 88  3.400000e+00  5.7600
# 89  3.450000e+00  6.0025
# 90  3.500000e+00  6.2500
# 91  3.550000e+00  6.5025
# 92  3.600000e+00  6.7600
# 93  3.650000e+00  7.0225
# 94  3.700000e+00  7.2900
# 95  3.750000e+00  7.5625
# 96  3.800000e+00  7.8400
# 97  3.850000e+00  8.1225
# 98  3.900000e+00  8.4100
# 99  3.950000e+00  8.7025
#
# [100 rows x 2 columns]

# %%
plt.scatter(xs,ys)

# %%
lr = 0.01
x = 4
log = []
for i in range(300):
    grad = 2 * x - 2
    x = x - grad * lr
    log.append(x)

# %%
import pandas as pd

# %%
pd.DataFrame(log).plot()

# %% [markdown]
# # vector SGD

# %%
y = (x - 1) ** 2

# %%
lr = 0.01
x = np.random.randn(10)
log = []
for i in range(300):
    grad = 2 * x - 2
    x = x - grad * lr
    log.append(x)

# %%
pd.DataFrame(log).plot()
